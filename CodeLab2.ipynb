# %% [markdown]
# ##Experimets with number of words

# %%
import numpy as np
import tensorflow as tf
import keras

print ("TensorFlow version: " + tf.__version__)
print ("Keras version: " + keras.__version__)

from keras import models
from keras import layers
# Out:
# TensorFlow version: 2.15.0
# Keras version: 2.15.0

# %%
from keras.datasets import imdb

def vectorize_sequences(sequences, dimension):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        # set specific indices of results[i] to 1s
        results[i, sequence] = 1.
    return results

def vectorize_data_float_labels(data, labels, dimension):
    # Our vectorized training data
    x = vectorize_sequences(data, dimension)
    # Our vectorized labels
    y = np.asarray(labels).astype('float32')
    return x, y

# %%
def Create3LModel(num_top_words, hl1 = 16, hl2 = 8):
    model = models.Sequential()
    model.add(layers.Dense(hl1, activation='relu', input_shape=(num_top_words,)))
    model.add(layers.Dense(hl2, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    return model

# %%
# Load IMDB data with the specified number of the most frequently words
num_top_words=5000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_top_words)

x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model5000 = Create3LModel(num_top_words=num_top_words, hl1 = 16, hl2 = 8)

model5000.summary()

model5000.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['acc'])

history5000 = model5000.fit(x_train, y_train,
                            epochs=50,
                            batch_size=256,
                            validation_data=(x_val, y_val))
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_54 (Dense)            (None, 16)                80016
#
#  dense_55 (Dense)            (None, 8)                 136
#
#  dense_56 (Dense)            (None, 1)                 9
#
# ...
# Total params: 80161 (313.13 KB)
# Trainable params: 80161 (313.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 98/98 [==============================] - 4s 36ms/step - loss: 0.4069 - acc: 0.8304 - val_loss: 0.2988 - val_acc: 0.8848
# Epoch 2/50
# 98/98 [==============================] - 2s 18ms/step - loss: 0.2522 - acc: 0.9034 - val_loss: 0.2796 - val_acc: 0.8864
# Epoch 3/50
# 98/98 [==============================] - 4s 40ms/step - loss: 0.2157 - acc: 0.9176 - val_loss: 0.2884 - val_acc: 0.8838
# Epoch 4/50
# ...

# %%
# Load IMDB data with the specified number of the most frequently words
num_top_words=10000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_top_words)

x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model10000 = Create3LModel(num_top_words=num_top_words, hl1 = 16, hl2 = 8)

model10000.summary()

model10000.compile(optimizer='rmsprop',
                   loss='binary_crossentropy',
                   metrics=['acc'])

history10000 = model10000.fit(x_train, y_train,
                              epochs=50,
                              batch_size=256,
                              validation_data=(x_val, y_val))
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_18 (Dense)            (None, 16)                160016
#
#  dense_19 (Dense)            (None, 8)                 136
#
#  dense_20 (Dense)            (None, 1)                 9
#
# ...
# Total params: 160161 (625.63 KB)
# Trainable params: 160161 (625.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 98/98 [==============================] - 7s 63ms/step - loss: 0.4184 - acc: 0.8404 - val_loss: 0.3064 - val_acc: 0.8862
# Epoch 2/50
# 98/98 [==============================] - 2s 21ms/step - loss: 0.2412 - acc: 0.9127 - val_loss: 0.2792 - val_acc: 0.8891
# Epoch 3/50
# 98/98 [==============================] - 3s 27ms/step - loss: 0.1930 - acc: 0.9283 - val_loss: 0.2854 - val_acc: 0.8864
# Epoch 4/50
# ...

# %%
# Load IMDB data with the specified number of the most frequently words
num_top_words=2000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_top_words)

x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model2000 = Create3LModel(num_top_words=num_top_words, hl1 = 16, hl2 = 8)

model2000.summary()

model2000.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['acc'])

history2000 = model2000.fit(x_train, y_train,
                            epochs=50,
                            batch_size=256,
                            validation_data=(x_val, y_val))
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_21 (Dense)            (None, 16)                32016
#
#  dense_22 (Dense)            (None, 8)                 136
#
#  dense_23 (Dense)            (None, 1)                 9
#
# ...
# Total params: 32161 (125.63 KB)
# Trainable params: 32161 (125.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 98/98 [==============================] - 4s 25ms/step - loss: 0.4500 - acc: 0.8092 - val_loss: 0.3359 - val_acc: 0.8680
# Epoch 2/50
# 98/98 [==============================] - 1s 8ms/step - loss: 0.2979 - acc: 0.8815 - val_loss: 0.3030 - val_acc: 0.8747
# Epoch 3/50
# 98/98 [==============================] - 1s 8ms/step - loss: 0.2686 - acc: 0.8910 - val_loss: 0.2999 - val_acc: 0.8744
# Epoch 4/50
# ...

# %%
# Load IMDB data with the specified number of the most frequently words
num_top_words=1000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_top_words)

x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model1000 = Create3LModel(num_top_words=num_top_words, hl1 = 16, hl2 = 8)

model1000.summary()

model1000.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['acc'])

history1000 = model1000.fit(x_train, y_train,
                            epochs=50,
                            batch_size=256,
                            validation_data=(x_val, y_val))
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_24 (Dense)            (None, 16)                16016
#
#  dense_25 (Dense)            (None, 8)                 136
#
#  dense_26 (Dense)            (None, 1)                 9
#
# ...
# Total params: 16161 (63.13 KB)
# Trainable params: 16161 (63.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 98/98 [==============================] - 2s 11ms/step - loss: 0.4945 - acc: 0.7744 - val_loss: 0.3772 - val_acc: 0.8441
# Epoch 2/50
# 98/98 [==============================] - 1s 5ms/step - loss: 0.3432 - acc: 0.8572 - val_loss: 0.3369 - val_acc: 0.8585
# Epoch 3/50
# 98/98 [==============================] - 1s 5ms/step - loss: 0.3192 - acc: 0.8665 - val_loss: 0.3275 - val_acc: 0.8619
# Epoch 4/50
# ...

# %%
# Load IMDB data with the specified number of the most frequently words
num_top_words=500
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_top_words)

x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model500 = Create3LModel(num_top_words=num_top_words, hl1 = 16, hl2 = 8)

model500.summary()

model500.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['acc'])

history500 = model500.fit(x_train, y_train,
                            epochs=50,
                            batch_size=256,
                            validation_data=(x_val, y_val))
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_27 (Dense)            (None, 16)                8016
#
#  dense_28 (Dense)            (None, 8)                 136
#
#  dense_29 (Dense)            (None, 1)                 9
#
# ...
# Total params: 8161 (31.88 KB)
# Trainable params: 8161 (31.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 98/98 [==============================] - 2s 8ms/step - loss: 0.5391 - acc: 0.7309 - val_loss: 0.4417 - val_acc: 0.8009
# Epoch 2/50
# 98/98 [==============================] - 1s 6ms/step - loss: 0.4011 - acc: 0.8263 - val_loss: 0.3963 - val_acc: 0.8244
# Epoch 3/50
# 98/98 [==============================] - 0s 5ms/step - loss: 0.3789 - acc: 0.8340 - val_loss: 0.3976 - val_acc: 0.8266
# Epoch 4/50
# ...

# %% [markdown]
# # 20 epochs

# %%
def Create3LModel(num_top_words, hl1 = 16, hl2 = 8):
    model = models.Sequential()
    model.add(layers.Dense(hl1, activation='relu', input_shape=(num_top_words,)))
    model.add(layers.Dense(hl2, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    return model

# %%
# Load IMDB data with the specified number of the most frequently words
num_top_words=5000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_top_words)

x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model5000_20 = Create3LModel(num_top_words=num_top_words, hl1 = 16, hl2 = 8)

model5000_20.summary()

model5000_20.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['acc'])

history5000_20 = model5000_20.fit(x_train, y_train,
                            epochs=20,
                            batch_size=256,
                            validation_data=(x_val, y_val))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 16)                80016
#
#  dense_4 (Dense)             (None, 8)                 136
#
#  dense_5 (Dense)             (None, 1)                 9
#
# ...
# Total params: 80161 (313.13 KB)
# Trainable params: 80161 (313.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 98/98 [==============================] - 4s 35ms/step - loss: 0.4068 - acc: 0.8396 - val_loss: 0.3026 - val_acc: 0.8843
# Epoch 2/20
# 98/98 [==============================] - 2s 16ms/step - loss: 0.2523 - acc: 0.9035 - val_loss: 0.2828 - val_acc: 0.8858
# Epoch 3/20
# 98/98 [==============================] - 2s 17ms/step - loss: 0.2171 - acc: 0.9187 - val_loss: 0.2889 - val_acc: 0.8827
# Epoch 4/20
# ...

# %%
# Load IMDB data with the specified number of the most frequently words
num_top_words=10000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_top_words)

x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model10000_20 = Create3LModel(num_top_words=num_top_words, hl1 = 16, hl2 = 8)

model10000_20.summary()

model10000_20.compile(optimizer='rmsprop',
                   loss='binary_crossentropy',
                   metrics=['acc'])

history10000_20 = model10000_20.fit(x_train, y_train,
                              epochs=20,
                              batch_size=256,
                              validation_data=(x_val, y_val))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 16)                160016
#
#  dense_7 (Dense)             (None, 8)                 136
#
#  dense_8 (Dense)             (None, 1)                 9
#
# ...
# Total params: 160161 (625.63 KB)
# Trainable params: 160161 (625.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 98/98 [==============================] - 6s 59ms/step - loss: 0.4063 - acc: 0.8404 - val_loss: 0.2995 - val_acc: 0.8864
# Epoch 2/20
# 98/98 [==============================] - 3s 30ms/step - loss: 0.2354 - acc: 0.9136 - val_loss: 0.2894 - val_acc: 0.8833
# Epoch 3/20
# 98/98 [==============================] - 3s 30ms/step - loss: 0.1894 - acc: 0.9306 - val_loss: 0.2857 - val_acc: 0.8855
# Epoch 4/20
# ...

# %%
# Load IMDB data with the specified number of the most frequently words
num_top_words=2000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_top_words)

x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model2000_20 = Create3LModel(num_top_words=num_top_words, hl1 = 16, hl2 = 8)

model2000_20.summary()

model2000_20.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['acc'])

history2000_20 = model2000_20.fit(x_train, y_train,
                            epochs=20,
                            batch_size=256,
                            validation_data=(x_val, y_val))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 16)                32016
#
#  dense_10 (Dense)            (None, 8)                 136
#
#  dense_11 (Dense)            (None, 1)                 9
#
# ...
# Total params: 32161 (125.63 KB)
# Trainable params: 32161 (125.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 98/98 [==============================] - 2s 14ms/step - loss: 0.5428 - acc: 0.7671 - val_loss: 0.4479 - val_acc: 0.8564
# Epoch 2/20
# 98/98 [==============================] - 1s 9ms/step - loss: 0.3560 - acc: 0.8762 - val_loss: 0.3598 - val_acc: 0.8590
# Epoch 3/20
# 98/98 [==============================] - 1s 9ms/step - loss: 0.2860 - acc: 0.8898 - val_loss: 0.3043 - val_acc: 0.8773
# Epoch 4/20
# ...

# %%
# Load IMDB data with the specified number of the most frequently words
num_top_words=1000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_top_words)

x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model1000_20 = Create3LModel(num_top_words=num_top_words, hl1 = 16, hl2 = 8)

model1000_20.summary()

model1000_20.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['acc'])

history1000_20 = model1000_20.fit(x_train, y_train,
                            epochs=20,
                            batch_size=256,
                            validation_data=(x_val, y_val))
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 16)                16016
#
#  dense_13 (Dense)            (None, 8)                 136
#
#  dense_14 (Dense)            (None, 1)                 9
#
# ...
# Total params: 16161 (63.13 KB)
# Trainable params: 16161 (63.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 98/98 [==============================] - 2s 11ms/step - loss: 0.5040 - acc: 0.7546 - val_loss: 0.3758 - val_acc: 0.8474
# Epoch 2/20
# 98/98 [==============================] - 1s 5ms/step - loss: 0.3455 - acc: 0.8589 - val_loss: 0.3366 - val_acc: 0.8586
# Epoch 3/20
# 98/98 [==============================] - 1s 6ms/step - loss: 0.3173 - acc: 0.8702 - val_loss: 0.3471 - val_acc: 0.8527
# Epoch 4/20
# ...

# %%
# Load IMDB data with the specified number of the most frequently words
num_top_words=500
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_top_words)

x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model500_20 = Create3LModel(num_top_words=num_top_words, hl1 = 16, hl2 = 8)

model500_20.summary()

model500_20.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['acc'])

history500_20 = model500_20.fit(x_train, y_train,
                            epochs=20,
                            batch_size=256,
                            validation_data=(x_val, y_val))
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_15 (Dense)            (None, 16)                8016
#
#  dense_16 (Dense)            (None, 8)                 136
#
#  dense_17 (Dense)            (None, 1)                 9
#
# ...
# Total params: 8161 (31.88 KB)
# Trainable params: 8161 (31.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 98/98 [==============================] - 1s 7ms/step - loss: 0.5231 - acc: 0.7403 - val_loss: 0.4280 - val_acc: 0.8075
# Epoch 2/20
# 98/98 [==============================] - 0s 5ms/step - loss: 0.3975 - acc: 0.8218 - val_loss: 0.3995 - val_acc: 0.8243
# Epoch 3/20
# 98/98 [==============================] - 0s 5ms/step - loss: 0.3791 - acc: 0.8325 - val_loss: 0.3860 - val_acc: 0.8314
# Epoch 4/20
# ...

# %% [markdown]
# # **PLOTS** 20 epochs and 50 epochs comparision

# %%
import matplotlib.pyplot as plt  # library for plotting math functions: https://matplotlib.org/stable/index.html

def Plot_4_AccuracyComparison(acc1, val_acc1, acc2, val_acc2, acc3, val_acc3, acc4, val_acc4, acc5, val_acc5, lab1 = '1', lab2 = '2', lab3 = '3', lab4 = '4', lab5 = '5'):
    plt.clf()   # clear figure
    plt.rcParams['figure.figsize'] = (20.0, 10.0) # set default size of plots
    epochs = range(len(acc1))
    plt.plot(epochs, acc1, 'bo', label='Training accuracy for ' + lab1)
    plt.plot(epochs, val_acc1, 'b', label='Validation accuracy for ' + lab1)
    plt.plot(epochs, acc2, 'ro', label='Training accuracy for ' + lab2)
    plt.plot(epochs, val_acc2, 'r', label='Validation accuracy for ' + lab2)
    plt.plot(epochs, acc3, 'go', label='Training accuracy for ' + lab3)
    plt.plot(epochs, val_acc3, 'g', label='Validation accuracy for ' + lab3)
    plt.plot(epochs, acc4, 'yo', label='Training accuracy for ' + lab4)
    plt.plot(epochs, val_acc4, 'y', label='Validation accuracy for ' + lab4)
    plt.plot(epochs, acc5, 'co', label='Training accuracy for ' + lab5)
    plt.plot(epochs, val_acc5, 'c', label='Validation accuracy for ' + lab5)
    plt.title('Comparison of Training and Validation Accuracies - 50 epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# %%
    def Plot_5_AccuracyComparison(acc1, val_acc1, acc2, val_acc2, acc3, val_acc3, acc4, val_acc4, acc5, val_acc5, lab1 = '1', lab2 = '2', lab3 = '3', lab4 = '4', lab5 = '5'):
      plt.clf()   # clear figure
      plt.rcParams['figure.figsize'] = (20.0, 10.0) # set default size of plots
      epochs = range(len(acc1))
      plt.plot(epochs, acc1, 'bo', label='Training accuracy for ' + lab1)
      plt.plot(epochs, val_acc1, 'b', label='Validation accuracy for ' + lab1)
      plt.plot(epochs, acc2, 'ro', label='Training accuracy for ' + lab2)
      plt.plot(epochs, val_acc2, 'r', label='Validation accuracy for ' + lab2)
      plt.plot(epochs, acc3, 'go', label='Training accuracy for ' + lab3)
      plt.plot(epochs, val_acc3, 'g', label='Validation accuracy for ' + lab3)
      plt.plot(epochs, acc4, 'yo', label='Training accuracy for ' + lab4)
      plt.plot(epochs, val_acc4, 'y', label='Validation accuracy for ' + lab4)
      plt.plot(epochs, acc5, 'co', label='Training accuracy for ' + lab5)
      plt.plot(epochs, val_acc5, 'c', label='Validation accuracy for ' + lab5)
      plt.title('Comparison of Training and Validation Accuracies - 20 epochs')
      plt.xlabel('Epochs')
      plt.ylabel('Accuracy')
      plt.legend()
      plt.show()

# %%
# Compare the accuracies of five training processes
acc5000 = history5000.history['acc']
val_acc5000 = history5000.history['val_acc']
acc10000 = history10000.history['acc']
val_acc10000 = history10000.history['val_acc']
acc2000 = history2000.history['acc']
val_acc2000 = history2000.history['val_acc']
acc1000 = history1000.history['acc']
val_acc1000 = history1000.history['val_acc']
acc500 = history500.history['acc']
val_acc500 = history500.history['val_acc']

Plot_4_AccuracyComparison(acc5000, val_acc5000, acc10000, val_acc10000, acc2000, val_acc2000, acc1000, val_acc1000, acc500, val_acc500, '5000', '10000', '2000', '1000', '500')

# %% [markdown]
# The graph shows the accuracy for 5 sets of the same data differing in the number of elements (from 10k to 500). It can be seen that the greater the number of elements in the data set, the greater the accuracy in the training set. During training, the sets of 10000, 5000, 2000 reach high values. For sets 1000 and 500, an increase in accuracy was noticed, but it is not as high as in previous attempts. Over the course of epochs, the set with 1000 elements almost matches the accuracy of the sets 10000, 5000, 2000, but it performs much worse on the validation set. For sets of 10000, 5000, 2000, the accuracy on the validation sets is similar. for sets of 1000 and 500 elements, they take much smaller values.

# %%
#comparision of five training process (20 epoch)

acc5000_20 = history5000_20.history['acc']
val_acc5000_20 = history5000_20.history['val_acc']
acc10000_20 = history10000_20.history['acc']
val_acc10000_20 = history10000_20.history['val_acc']
acc2000_20 = history2000_20.history['acc']
val_acc2000_20 = history2000_20.history['val_acc']
acc1000_20 = history1000_20.history['acc']
val_acc1000_20 = history1000_20.history['val_acc']
acc500_20 = history500_20.history['acc']
val_acc500_20 = history500_20.history['val_acc']

Plot_5_AccuracyComparison(acc5000_20, val_acc5000_20, acc10000_20, val_acc10000_20, acc2000_20, val_acc2000_20, acc1000_20, val_acc1000_20, acc500_20, val_acc500_20, '5000', '10000', '2000', '1000', '500')

# %% [markdown]
# The graph, like the previous one, shows the accuracy on validation and training sets for models trained on sets of 1000, 5000, 2000, 1000, 500 elements, but the number of epochs was 20. In this case, the differences between subsequent trials were much greater. Ultimately, all models achieved over 0.85 accuracy for the training set and over 0.8 for the validation set. The results are similar to the case with 50 epochs.

# %%
import matplotlib.pyplot as plt  # library for plotting math functions: https://matplotlib.org/stable/index.html
#oryginal codelab
def Plot_4_LossComparison(loss1, val_loss1, loss2, val_loss2, loss3, val_loss3, loss4, val_loss4, loss5, val_loss5, lab1 = '1', lab2 = '2', lab3 = '3', lab4 = '4', lab5 = '5'):
    plt.clf()   # clear figure
    plt.rcParams['figure.figsize'] = (25.0, 5.0) # set default size of plots
    epochs = range(len(loss1))
    plt.plot(epochs, loss1, 'bo', label='Training loss for ' + lab1)
    plt.plot(epochs, val_loss1, 'b', label='Validation loss for ' + lab1)
    plt.plot(epochs, loss2, 'ro', label='Training loss for ' + lab2)
    plt.plot(epochs, val_loss2, 'r', label='Validation loss for ' + lab2)
    plt.plot(epochs, loss3, 'go', label='Training loss for ' + lab3)
    plt.plot(epochs, val_loss3, 'g', label='Validation loss for ' + lab3)
    plt.plot(epochs, loss4, 'yo', label='Training loss for ' + lab4)
    plt.plot(epochs, val_loss4, 'y', label='Validation loss for ' + lab4)
    plt.plot(epochs, loss5, 'co', label='Training loss for ' + lab5)
    plt.plot(epochs, val_loss5, 'c', label='Validation loss for ' + lab5)
    plt.title('Comparison of Training and Validation Losses - 50 epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
# 20 epochs

def Plot_5_LossComparison(loss1, val_loss1, loss2, val_loss2, loss3, val_loss3, loss4, val_loss4, loss5, val_loss5, lab1 = '1', lab2 = '2', lab3 = '3', lab4 = '4', lab5 = '5'):
    plt.clf()   # clear figure
    plt.rcParams['figure.figsize'] = (25.0, 5.0) # set default size of plots
    epochs = range(len(loss1))
    plt.plot(epochs, loss1, 'bo', label='Training loss for ' + lab1)
    plt.plot(epochs, val_loss1, 'b', label='Validation loss for ' + lab1)
    plt.plot(epochs, loss2, 'ro', label='Training loss for ' + lab2)
    plt.plot(epochs, val_loss2, 'r', label='Validation loss for ' + lab2)
    plt.plot(epochs, loss3, 'go', label='Training loss for ' + lab3)
    plt.plot(epochs, val_loss3, 'g', label='Validation loss for ' + lab3)
    plt.plot(epochs, loss4, 'yo', label='Training loss for ' + lab4)
    plt.plot(epochs, val_loss4, 'y', label='Validation loss for ' + lab4)
    plt.plot(epochs, loss5, 'co', label='Training loss for ' + lab5)
    plt.plot(epochs, val_loss5, 'c', label='Validation loss for ' + lab5)
    plt.title('Comparison of Training and Validation Losses - 20 epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
# Compare the losses of three training processes
loss5000 = history5000.history['loss']
val_loss5000 = history5000.history['val_loss']
loss10000 = history10000.history['loss']
val_loss10000 = history10000.history['val_loss']
loss2000 = history2000.history['loss']
val_loss2000 = history2000.history['val_loss']
loss1000 = history1000.history['loss']
val_loss1000 = history1000.history['val_loss']
loss500 = history500.history['loss']
val_loss500 = history500.history['val_loss']

Plot_4_LossComparison(loss5000, val_loss5000, loss10000, val_loss10000, loss2000, val_loss2000, loss1000, val_loss1000, loss500, val_loss500, '5000', '10000', '2000', '1000', '500')

# %% [markdown]
# The graph shows the losses for 5 cases of trained models for sets with 10000, 5000, 2000, 1000, 500 elements. In the case of the validation set, we see the phenomenon of overfitting. This means that models learn patterns by heart and do not respond properly to new data not yet seen by the model. This is an invalid property. The model makes more and more errors as each epoch progresses. The larger the set, the greater the overtraining. The model that was trained on a set of 500 elements has the least overfitting. For the training set, we can notice decreasing loss values with subsequent epochs, the highest loss values are for the model trained on a 500-element set, and sets 10,000, 5,000, 1,000, 2,000 achieve comparably low values. All of these tests should be further improved to achieve the best results.

# %%
# Compare the losses of five training processes
loss5000_20 = history5000_20.history['loss']
val_loss5000_20 = history5000_20.history['val_loss']
loss10000_20 = history10000_20.history['loss']
val_loss10000_20 = history10000_20.history['val_loss']
loss2000_20 = history2000_20.history['loss']
val_loss2000_20 = history2000_20.history['val_loss']
loss1000_20 = history1000_20.history['loss']
val_loss1000_20 = history1000_20.history['val_loss']
loss500_20 = history500_20.history['loss']
val_loss500_20 = history500_20.history['val_loss']

Plot_5_LossComparison(loss5000_20, val_loss5000_20, loss10000_20, val_loss10000_20, loss2000_20, val_loss2000_20, loss1000_20, val_loss1000_20, loss500_20, val_loss500_20, '5000', '10000', '2000', '1000', '500')

# %% [markdown]
# The graph shows the loss functions for models trained on sets of 10000, 5000, 2000, 1000, 500 elements for 20 epochs. The values obtained when training for 20 epochs are much lower than in the case of models trained for 50 epochs for the same values of elements in the set (even 2 times smaller). In the case of models trained on sets of 10,000 and 5,000, the loss values are very high, even 0.8. The situation stabilizes in the case of sets of 2000, 1000 and 500 elements, but overfitting is still present. This means that the models should still be improved to eliminate overfitting.

# %%
#diffrent number of words only
argmax1 = np.argmax(val_acc5000)
argmax2 = np.argmax(val_acc10000)
argmax3 = np.argmax(val_acc2000)
argmax4 = np.argmax(val_acc1000)
argmax5 = np.argmax(val_acc500)
print ('Max accuracy for model 1 is: ', val_acc5000[argmax1], ', achieved in the ', argmax1 , 'epoch.')
print ('Max accuracy for model 2 is: ', val_acc10000[argmax2], ', achieved in the ', argmax2 , 'epoch.')
print ('Max accuracy for model 3 is: ', val_acc2000[argmax3], ', achieved in the ', argmax3 , 'epoch.')
print ('Max accuracy for model 4 is: ', val_acc1000[argmax4], ', achieved in the ', argmax4 , 'epoch.')
print ('Max accuracy for model 5 is: ', val_acc500[argmax5], ', achieved in the ', argmax5 , 'epoch.')
# Out:
# Max accuracy for model 1 is:  0.8830400109291077 , achieved in the  2 epoch.
# Max accuracy for model 2 is:  0.8890799880027771 , achieved in the  1 epoch.
# Max accuracy for model 3 is:  0.8747199773788452 , achieved in the  1 epoch.
# Max accuracy for model 4 is:  0.8619199991226196 , achieved in the  2 epoch.
# Max accuracy for model 5 is:  0.8332399725914001 , achieved in the  7 epoch.

# %%
#diffrent number of words, 20 epoch
argmax11 = np.argmax(val_acc5000_20)
argmax22 = np.argmax(val_acc10000_20)
argmax33 = np.argmax(val_acc2000_20)
argmax44 = np.argmax(val_acc1000_20)
argmax55 = np.argmax(val_acc500_20)
print ('Max accuracy for model 1 is: ', val_acc5000_20[argmax11], ', achieved in the ', argmax11 , 'epoch.')
print ('Max accuracy for model 2 is: ', val_acc10000_20[argmax22], ', achieved in the ', argmax22 , 'epoch.')
print ('Max accuracy for model 3 is: ', val_acc2000_20[argmax33], ', achieved in the ', argmax33 , 'epoch.')
print ('Max accuracy for model 4 is: ', val_acc1000_20[argmax44], ', achieved in the ', argmax44 , 'epoch.')
print ('Max accuracy for model 5 is: ', val_acc500_20[argmax55], ', achieved in the ', argmax55 , 'epoch.')
# Out:
# Max accuracy for model 1 is:  0.8857600092887878 , achieved in the  1 epoch.
# Max accuracy for model 2 is:  0.8863999843597412 , achieved in the  0 epoch.
# Max accuracy for model 3 is:  0.8772799968719482 , achieved in the  2 epoch.
# Max accuracy for model 4 is:  0.8600000143051147 , achieved in the  4 epoch.
# Max accuracy for model 5 is:  0.8331999778747559 , achieved in the  3 epoch.

# %% [markdown]
# Comparison of the maximum accuracies from training models on sets of 10000, 5000, 2000, 1000, 500 elements for epoch values of 20 and 50 indicates that they are very similar. By reducing the value of epochs to 20, we do not lose the accuracy of the model (only 3 digits after the decimal point differ). In all cases, a value above 0.8 was achieved. The highest value was observed for the model trained on a set of 10,000 trained for 50 epochs, for 20 epochs a slightly lower value was achieved.

# %% [markdown]
# For further work, it was decided to choose a model trained for 20 epochs and trained on a set of 2000 elements. It is the best compromise between high accuracy and the values assumed by the loss functions.

# %% [markdown]
# ##20 epochs and 2000 elements in dataset experiments

# %%
# oryginal
num_top_words=2000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_top_words)

x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model2 = Create3LModel(num_top_words=num_top_words, hl1 = 16, hl2 = 8)

model2.summary()

model2.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['acc'])

history2 = model2.fit(x_train, y_train,
                            epochs=20,
                            batch_size=256,
                            validation_data=(x_val, y_val))
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_57 (Dense)            (None, 16)                32016
#
#  dense_58 (Dense)            (None, 8)                 136
#
#  dense_59 (Dense)            (None, 1)                 9
#
# ...
# Total params: 32161 (125.63 KB)
# Trainable params: 32161 (125.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 98/98 [==============================] - 2s 18ms/step - loss: 0.4501 - acc: 0.8011 - val_loss: 0.3288 - val_acc: 0.8683
# Epoch 2/20
# 98/98 [==============================] - 1s 8ms/step - loss: 0.2971 - acc: 0.8802 - val_loss: 0.3001 - val_acc: 0.8752
# Epoch 3/20
# 98/98 [==============================] - 1s 7ms/step - loss: 0.2703 - acc: 0.8903 - val_loss: 0.2993 - val_acc: 0.8745
# Epoch 4/20
# ...

# %%
#
num_top_words=2000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_top_words)

x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model3 = Create3LModel(num_top_words=num_top_words, hl1 = 8, hl2 = 4)

model3.summary()

model3.compile(optimizer='rmsprop',
               loss='binary_crossentropy',
               metrics=['acc'])

history3 = model3.fit(x_train, y_train,
                      epochs=20,
                      batch_size=256,
                      validation_data=(x_val, y_val))
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_60 (Dense)            (None, 8)                 16008
#
#  dense_61 (Dense)            (None, 4)                 36
#
#  dense_62 (Dense)            (None, 1)                 5
#
# ...
# Total params: 16049 (62.69 KB)
# Trainable params: 16049 (62.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 98/98 [==============================] - 3s 20ms/step - loss: 0.5582 - acc: 0.7500 - val_loss: 0.4626 - val_acc: 0.8553
# Epoch 2/20
# 98/98 [==============================] - 2s 17ms/step - loss: 0.3772 - acc: 0.8723 - val_loss: 0.3675 - val_acc: 0.8540
# Epoch 3/20
# 98/98 [==============================] - 1s 9ms/step - loss: 0.2955 - acc: 0.8872 - val_loss: 0.3324 - val_acc: 0.8643
# Epoch 4/20
# ...

# %%
# Load IMDB data with the specified number of the most frequently words
num_top_words=2000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_top_words)

x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model1 = Create3LModel(num_top_words=num_top_words, hl1 = 64, hl2 = 32)

model1.summary()

model1.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['acc'])

history1 = model1.fit(x_train, y_train,
                      epochs=20,
                      batch_size=256,
                      validation_data=(x_val, y_val))
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_66 (Dense)            (None, 64)                128064
#
#  dense_67 (Dense)            (None, 32)                2080
#
#  dense_68 (Dense)            (None, 1)                 33
#
# ...
# Total params: 130177 (508.50 KB)
# Trainable params: 130177 (508.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 98/98 [==============================] - 3s 22ms/step - loss: 0.4100 - acc: 0.8167 - val_loss: 0.3080 - val_acc: 0.8730
# Epoch 2/20
# 98/98 [==============================] - 1s 14ms/step - loss: 0.2898 - acc: 0.8819 - val_loss: 0.3056 - val_acc: 0.8738
# Epoch 3/20
# 98/98 [==============================] - 1s 15ms/step - loss: 0.2606 - acc: 0.8922 - val_loss: 0.3117 - val_acc: 0.8691
# Epoch 4/20
# ...

# %%
import matplotlib.pyplot as plt  # library for plotting math functions: https://matplotlib.org/stable/index.html

def Plot_4_AccuracyComparison(acc1, val_acc1, acc2, val_acc2, acc3, val_acc3, lab1 = '1', lab2 = '2', lab3 = '3'):
    plt.clf()   # clear figure
    plt.rcParams['figure.figsize'] = (20.0, 10.0) # set default size of plots
    epochs = range(len(acc1))
    plt.plot(epochs, acc1, 'bo', label='Training accuracy for ' + lab1)
    plt.plot(epochs, val_acc1, 'b', label='Validation accuracy for ' + lab1)
    plt.plot(epochs, acc2, 'ro', label='Training accuracy for ' + lab2)
    plt.plot(epochs, val_acc2, 'r', label='Validation accuracy for ' + lab2)
    plt.plot(epochs, acc3, 'go', label='Training accuracy for ' + lab3)
    plt.plot(epochs, val_acc3, 'g', label='Validation accuracy for ' + lab3)
    plt.title('Comparison of Training and Validation Accuracies - different units, 20 epochs, 2000elements in dataset')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# %%
# Compare the accuracies of five training processes
acc1 = history1.history['acc']
val_acc1 = history1.history['val_acc']
acc2 = history2.history['acc']
val_acc2 = history2.history['val_acc']
acc3 = history3.history['acc']
val_acc3 = history3.history['val_acc']

Plot_4_AccuracyComparison(acc1, val_acc1, acc2, val_acc2, acc3, val_acc3, '64x32', '16x8', '8x4')

# %% [markdown]
# The graph shows the accuracy of the model over subsequent epochs. For all cases it is approximately 0.9, and for 64x32 even over 0.95. All these values are high and satisfactory. However, in the case of 64x32, the overtraining is very high, the loss function increases very quickly. In the case of 8X4 and 16X8, the loss function also increases, but the impact of overtraining is already visibly reduced. the 16x8 model is an earlier stage model.

# %%
def Plot_5_LossComparison(loss1, val_loss1, loss2, val_loss2, loss3, val_loss3, lab1 = '1', lab2 = '2', lab3 = '3'):
    plt.clf()   # clear figure
    plt.rcParams['figure.figsize'] = (25.0, 5.0) # set default size of plots
    epochs = range(len(loss1))
    plt.plot(epochs, loss1, 'bo', label='Training loss for ' + lab1)
    plt.plot(epochs, val_loss1, 'b', label='Validation loss for ' + lab1)
    plt.plot(epochs, loss2, 'ro', label='Training loss for ' + lab2)
    plt.plot(epochs, val_loss2, 'r', label='Validation loss for ' + lab2)
    plt.plot(epochs, loss3, 'go', label='Training loss for ' + lab3)
    plt.plot(epochs, val_loss3, 'g', label='Validation loss for ' + lab3)
    plt.title('Comparison of Training and Validation Losses - 20 epochs, 2000 elements in dataset. different numbers of units')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
# Compare the losses of five training processes
loss1 = history1.history['loss']
val_loss1 = history1.history['val_loss']
loss2 = history2.history['loss']
val_loss2 = history2.history['val_loss']
loss3 = history3.history['loss']
val_loss3 = history3.history['val_loss']

Plot_5_LossComparison(loss1, val_loss1, loss2, val_loss2, loss3, val_loss3, '64x32', '16x8', '8x4')

# %% [markdown]
# The graph shows a comparison of losses for models trained with different unit values. The set had 2000 elements, the number of epochs was 20. For the 8x set, the loss function increases slightly, the problem of overfitting is still visible, while in comparison to the remaining ones (64x32 and 16x8) the result is satisfactory (below the value of 0.4). This is the lowest loss result of the model achieved so far. in the case of 64x32, overfitting is visible, the loss function takes high values, close to 0.9. This means that reducing the number of units has a positive effect on eliminating overtraining. Applying an overly complicated model to undemanding data leads to overtraining of the model. the 16x8 model is an earlier stage model

# %%
#diffrent number of words, 20 epoch
argmax1 = np.argmax(val_acc1)
argmax2 = np.argmax(val_acc2)
argmax3 = np.argmax(val_acc3)
print ('Max accuracy for model 1 is: ', val_acc1[argmax1], ', achieved in the ', argmax1, 'epoch.')
print ('Max accuracy for model 2 is: ', val_acc2[argmax2], ', achieved in the ', argmax2 , 'epoch.')
print ('Max accuracy for model 3 is: ', val_acc3[argmax3], ', achieved in the ', argmax3, 'epoch.')
# Out:
# Max accuracy for model 1 is:  0.8737999796867371 , achieved in the  1 epoch.
# Max accuracy for model 2 is:  0.8752400279045105 , achieved in the  1 epoch.
# Max accuracy for model 3 is:  0.8744400143623352 , achieved in the  3 epoch.

# %% [markdown]
# The maximum accuracy in all cases is about 87. For further experiments, a model trained on a set of 2000 elements, an epoch value of 20 and a number of units of 8x4 were selected.

# %% [markdown]
# ##More experiments

# %%
num_top_words=2000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_top_words)

x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model11 = Create3LModel(num_top_words=num_top_words, hl1 = 8, hl2 = 4)

model11.summary()

model11.compile(optimizer='rmsprop',
               loss='binary_crossentropy',
               metrics=['acc'])

history11 = model11.fit(x_train, y_train,
                      epochs=20,
                      batch_size=256,
                      validation_data=(x_val, y_val))
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_69 (Dense)            (None, 8)                 16008
#
#  dense_70 (Dense)            (None, 4)                 36
#
#  dense_71 (Dense)            (None, 1)                 5
#
# ...
# Total params: 16049 (62.69 KB)
# Trainable params: 16049 (62.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 98/98 [==============================] - 4s 34ms/step - loss: 0.5744 - acc: 0.7285 - val_loss: 0.4884 - val_acc: 0.8418
# Epoch 2/20
# 98/98 [==============================] - 2s 22ms/step - loss: 0.3970 - acc: 0.8713 - val_loss: 0.3347 - val_acc: 0.8761
# Epoch 3/20
# 98/98 [==============================] - 3s 32ms/step - loss: 0.2914 - acc: 0.8904 - val_loss: 0.3610 - val_acc: 0.8476
# Epoch 4/20
# ...

# %%
def Create3LModelL1(num_top_words, hl1 = 8, hl2 = 4):
    model = models.Sequential()
    model.add(layers.Dense(hl1, kernel_regularizer=regularizers.l1(0.001),
                           activation='relu', input_shape=(num_top_words,)))
    model.add(layers.Dense(hl2, kernel_regularizer=regularizers.l1(0.001),
                           activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    return model

def Create3LModelL2(num_top_words, hl1 = 8, hl2 = 4):
    model = models.Sequential()
    model.add(layers.Dense(hl1, kernel_regularizer=regularizers.l2(0.001),
                           activation='relu', input_shape=(num_top_words,)))
    model.add(layers.Dense(hl2, kernel_regularizer=regularizers.l2(0.001),
                           activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    return model

def Create3LModelL1L2(num_top_words, hl1 = 8, hl2 = 4):
    model = models.Sequential()
    model.add(layers.Dense(hl1, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001),
                           activation='relu', input_shape=(num_top_words,)))
    model.add(layers.Dense(hl2, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001),
                           activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    return model

# %%
def Create3LModelL1Dropout(num_top_words, hl1 = 8, hl2 = 4, probdrop=0.5):
    model = models.Sequential()
    model.add(layers.Dense(hl1, kernel_regularizer=regularizers.l1(0.001),
                           activation='relu', input_shape=(num_top_words,)))
    model.add(layers.Dropout(probdrop))
    model.add(layers.Dense(hl2, kernel_regularizer=regularizers.l1(0.001),
                           activation='relu'))
    model.add(layers.Dropout(probdrop))
    model.add(layers.Dense(1, activation='sigmoid'))
    return model

# %%
num_top_words=2000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_top_words)

x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model22 = Create3LModelL1(num_top_words=num_top_words, hl1 = 8, hl2 = 4)

model22.summary()

model22.compile(optimizer='rmsprop',
               loss='binary_crossentropy',
               metrics=['acc'])

history22 = model22.fit(x_train, y_train,
                      epochs=20,
                      batch_size=256,
                      validation_data=(x_val, y_val))
# Out:
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_72 (Dense)            (None, 8)                 16008
#
#  dense_73 (Dense)            (None, 4)                 36
#
#  dense_74 (Dense)            (None, 1)                 5
#
# ...
# Total params: 16049 (62.69 KB)
# Trainable params: 16049 (62.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 98/98 [==============================] - 5s 28ms/step - loss: 0.6937 - acc: 0.7881 - val_loss: 0.5407 - val_acc: 0.8406
# Epoch 2/20
# 98/98 [==============================] - 2s 17ms/step - loss: 0.4916 - acc: 0.8568 - val_loss: 0.4912 - val_acc: 0.8450
# Epoch 3/20
# 98/98 [==============================] - 2s 16ms/step - loss: 0.4499 - acc: 0.8642 - val_loss: 0.4476 - val_acc: 0.8629
# Epoch 4/20
# ...

# %%
num_top_words=2000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_top_words)

x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model33 = Create3LModelL2(num_top_words=num_top_words, hl1 = 8, hl2 = 4)

model33.summary()

model33.compile(optimizer='rmsprop',
               loss='binary_crossentropy',
               metrics=['acc'])

history33 = model33.fit(x_train, y_train,
                      epochs=20,
                      batch_size=256,
                      validation_data=(x_val, y_val))
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_75 (Dense)            (None, 8)                 16008
#
#  dense_76 (Dense)            (None, 4)                 36
#
#  dense_77 (Dense)            (None, 1)                 5
#
# ...
# Total params: 16049 (62.69 KB)
# Trainable params: 16049 (62.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 98/98 [==============================] - 3s 22ms/step - loss: 0.4856 - acc: 0.8073 - val_loss: 0.3845 - val_acc: 0.8601
# Epoch 2/20
# 98/98 [==============================] - 1s 11ms/step - loss: 0.3399 - acc: 0.8806 - val_loss: 0.3354 - val_acc: 0.8756
# Epoch 3/20
# 98/98 [==============================] - 1s 10ms/step - loss: 0.3084 - acc: 0.8884 - val_loss: 0.3269 - val_acc: 0.8777
# Epoch 4/20
# ...

# %%
num_top_words=2000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_top_words)

x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model44 = Create3LModelL1L2(num_top_words=num_top_words, hl1 = 8, hl2 = 4)

model44.summary()

model44.compile(optimizer='rmsprop',
               loss='binary_crossentropy',
               metrics=['acc'])

history44 = model44.fit(x_train, y_train,
                      epochs=20,
                      batch_size=256,
                      validation_data=(x_val, y_val))
# Out:
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_78 (Dense)            (None, 8)                 16008
#
#  dense_79 (Dense)            (None, 4)                 36
#
#  dense_80 (Dense)            (None, 1)                 5
#
# ...
# Total params: 16049 (62.69 KB)
# Trainable params: 16049 (62.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7596 - acc: 0.6930 - val_loss: 0.6218 - val_acc: 0.7767
# Epoch 2/20
# 98/98 [==============================] - 1s 15ms/step - loss: 0.5978 - acc: 0.8142 - val_loss: 0.5816 - val_acc: 0.8483
# Epoch 3/20
# 98/98 [==============================] - 2s 16ms/step - loss: 0.5661 - acc: 0.8366 - val_loss: 0.5519 - val_acc: 0.8405
# Epoch 4/20
# ...

# %%
num_top_words=2000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_top_words)

x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model55 = Create3LModelL1Dropout(num_top_words=num_top_words, hl1 = 8, hl2 = 4)

model55.summary()

model55.compile(optimizer='rmsprop',
               loss='binary_crossentropy',
               metrics=['acc'])

history55 = model55.fit(x_train, y_train,
                      epochs=20,
                      batch_size=256,
                      validation_data=(x_val, y_val))
# Out:
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_81 (Dense)            (None, 8)                 16008
#
#  dropout_2 (Dropout)         (None, 8)                 0
#
#  dense_82 (Dense)            (None, 4)                 36
#
#  dropout_3 (Dropout)         (None, 4)                 0
#
#  dense_83 (Dense)            (None, 1)                 5
#
# ...
# Total params: 16049 (62.69 KB)
# Trainable params: 16049 (62.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 98/98 [==============================] - 5s 30ms/step - loss: 0.8398 - acc: 0.5880 - val_loss: 0.6535 - val_acc: 0.8287
# Epoch 2/20
# 98/98 [==============================] - 3s 35ms/step - loss: 0.6626 - acc: 0.6718 - val_loss: 0.5528 - val_acc: 0.8326
# Epoch 3/20
# ...

# %%
import matplotlib.pyplot as plt  # library for plotting math functions: https://matplotlib.org/stable/index.html
#oryginal codelab
def Plot_4_AccuracyComparison(acc1, val_acc1, acc2, val_acc2, acc3, val_acc3, acc4, val_acc4, acc5, val_acc5, lab1 = '1', lab2 = '2', lab3 = '3', lab4 = '4', lab5 = '5'):
    plt.clf()   # clear figure
    plt.rcParams['figure.figsize'] = (20.0, 10.0) # set default size of plots
    epochs = range(len(acc1))
    plt.plot(epochs, acc1, 'bo', label='Training accuracy for ' + lab1)
    plt.plot(epochs, val_acc1, 'b', label='Validation accuracy for ' + lab1)
    plt.plot(epochs, acc2, 'ro', label='Training accuracy for ' + lab2)
    plt.plot(epochs, val_acc2, 'r', label='Validation accuracy for ' + lab2)
    plt.plot(epochs, acc3, 'go', label='Training accuracy for ' + lab3)
    plt.plot(epochs, val_acc3, 'g', label='Validation accuracy for ' + lab3)
    plt.plot(epochs, acc4, 'yo', label='Training accuracy for ' + lab4)
    plt.plot(epochs, val_acc4, 'y', label='Validation accuracy for ' + lab4)
    plt.plot(epochs, acc5, 'co', label='Training accuracy for ' + lab5)
    plt.plot(epochs, val_acc5, 'c', label='Validation accuracy for ' + lab5)
    plt.title('Comparison of Training and Validation Accuracies')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# %%
# Compare the accuracies of five training processes
acc11 = history11.history['acc']
val_acc11 = history11.history['val_acc']
acc22 = history22.history['acc']
val_acc22 = history22.history['val_acc']
acc33 = history33.history['acc']
val_acc33 = history33.history['val_acc']
acc44 = history44.history['acc']
val_acc44 = history44.history['val_acc']
acc55 = history55.history['acc']
val_acc55 = history55.history['val_acc']

Plot_4_AccuracyComparison(acc11, val_acc11, acc22, val_acc22, acc33, val_acc33, acc44, val_acc44, acc55, val_acc55, 'oryginal, 20 epochs, 2000 elements in dataset, 8x4', 'L1', 'L2', 'L1L2','Dropout')

# %% [markdown]
# The graph shows the accuracy values obtained throughout the training process. For the graph without regularization and without dropout, the highest accuracy values were obtained (about 0.9), followed by the L2 graph. Compared to other dropout charts, it has the lowest accuracy values of 0.7-0.75.

# %%
def Plot_5_LossComparison(loss1, val_loss1, loss2, val_loss2, loss3, val_loss3, loss4, val_loss4, loss5, val_loss5, lab1 = '1', lab2 = '2', lab3 = '3', lab4 = '4', lab5 = '5'):
    plt.clf()   # clear figure
    plt.rcParams['figure.figsize'] = (25.0, 5.0) # set default size of plots
    epochs = range(len(loss1))
    plt.plot(epochs, loss1, 'bo', label='Training loss for ' + lab1)
    plt.plot(epochs, val_loss1, 'b', label='Validation loss for ' + lab1)
    plt.plot(epochs, loss2, 'ro', label='Training loss for ' + lab2)
    plt.plot(epochs, val_loss2, 'r', label='Validation loss for ' + lab2)
    plt.plot(epochs, loss3, 'go', label='Training loss for ' + lab3)
    plt.plot(epochs, val_loss3, 'g', label='Validation loss for ' + lab3)
    plt.plot(epochs, loss4, 'yo', label='Training loss for ' + lab4)
    plt.plot(epochs, val_loss4, 'y', label='Validation loss for ' + lab4)
    plt.plot(epochs, loss5, 'co', label='Training loss for ' + lab5)
    plt.plot(epochs, val_loss5, 'c', label='Validation loss for ' + lab5)
    plt.title('Comparison of Training and Validation Losses - 20 epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
# Compare the losses of three training processes
loss11 = history11.history['loss']
val_loss11 = history11.history['val_loss']
loss22 = history22.history['loss']
val_loss22 = history22.history['val_loss']
loss33 = history33.history['loss']
val_loss33 = history33.history['val_loss']
loss44 = history44.history['loss']
val_loss44 = history44.history['val_loss']
loss55 = history55.history['loss']
val_loss55 = history55.history['val_loss']

Plot_4_LossComparison(loss11, val_loss11, loss22, val_loss22, loss33, val_loss33, loss44, val_loss44, loss55, val_loss55, 'oryginal, 20 epochs, 2000 elements in dataset, 8x4', 'L1', 'L2', 'L1L2','Dropout')

# %% [markdown]
# In the presented case, the loss functions are still not perfect, but they already have the desired shape and quite low loss values. The problem of overfitting is becoming less and less noticeable. the best results were achieved for the original model, which came from previous attempts and no changes were made to it, and for example L2 with regularization. In these cases the losses are less than 0.4. Experiments still need to be performed to achieve better results, but at this point it has already been possible to obtain lower loss values than in the initially presented examples.

# %%
argmax1 = np.argmax(val_acc11)
argmax2 = np.argmax(val_acc22)
argmax3 = np.argmax(val_acc33)
argmax4 = np.argmax(val_acc44)
argmax5 = np.argmax(val_acc55)
print ('Max accuracy for model 1 is: ', val_acc11[argmax1], ', achieved in the ', argmax1 , 'epoch.')
print ('Max accuracy for model 2 is: ', val_acc22[argmax2], ', achieved in the ', argmax2 , 'epoch.')
print ('Max accuracy for model 3 is: ', val_acc33[argmax3], ', achieved in the ', argmax3 , 'epoch.')
print ('Max accuracy for model 4 is: ', val_acc44[argmax4], ', achieved in the ', argmax4 , 'epoch.')
print ('Max accuracy for model 5 is: ', val_acc55[argmax5], ', achieved in the ', argmax5 , 'epoch.')
# Out:
# Max accuracy for model 1 is:  0.8761199712753296 , achieved in the  1 epoch.
# Max accuracy for model 2 is:  0.8752400279045105 , achieved in the  14 epoch.
# Max accuracy for model 3 is:  0.8776800036430359 , achieved in the  2 epoch.
# Max accuracy for model 4 is:  0.876479983329773 , achieved in the  14 epoch.
# Max accuracy for model 5 is:  0.8694000244140625 , achieved in the  17 epoch.

# %% [markdown]
# In all cases, the accuracy is similar, by choosing the L2 chart or the original one from earlier tests for further tests, we will not lose accuracy and will only gain less overtraining.

# %% [markdown]
# ##Own dataset experiments

# %%
import csv
file = open('winequality-red.csv')

file_with_wines = csv.reader(file)

header = []
header = next(file_with_wines)
header
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
rows = []
for row in file_with_wines:
        rows.append(row)
rows
# Out:
# [['7.4',
#   '0.7',
#   '0.0',
#   '1.9',
#   '0.076',
#   '11.0',
#   '34.0',
#   '0.9978',
#   '3.51',
#   '0.56',
#   '9.4',
#   '5'],
#  ['7.8',
#   '0.88',
#   '0.0',
#   '2.6',
#   '0.098',
#   '25.0',
#   '67.0',
#   '0.9968',
#   '3.2',
#   '0.68',
#   '9.8',
#   '5'],
#  ['7.8',
#   '0.76',
#   '0.04',
#   '2.3',
#   '0.092',
#   '15.0',
#   '54.0',
#   '0.997',
#   '3.26',
#   '0.65',
#   '9.8',
#   '5'],
#  ['11.2',
#   '0.28',
#   '0.56',
#   '1.9',
#   '0.075',
#   '17.0',
#   '60.0',
#   '0.998',
#   '3.16',
#   '0.58',
#   '9.8',
#   '6'],
#  ['7.4',
#   '0.7',
#   '0.0',
#   '1.9',
#   '0.076',
#   '11.0',
#   '34.0',
#   '0.9978',
#   '3.51',
#   '0.56',
#   '9.4',
#   '5'],
#  ['7.4',
#   '0.66',
#   '0.0',
#   '1.8',
#   '0.075',
#   '13.0',
#   '40.0',
#   '0.9978',
#   '3.51',
#   '0.56',
#   '9.4',
#   '5'],
#  ['7.9',
#   '0.6',
#   '0.06',
#   '1.6',
#   '0.069',
#   '15.0',
#   '59.0',
#   '0.9964',
#   '3.3',
#   '0.46',
#   '9.4',
#   '5'],
#  ['7.3',
# ...

# %%
rows[:5]
# Out:
# [['7.4',
#   '0.7',
#   '0.0',
#   '1.9',
#   '0.076',
#   '11.0',
#   '34.0',
#   '0.9978',
#   '3.51',
#   '0.56',
#   '9.4',
#   '5'],
#  ['7.8',
#   '0.88',
#   '0.0',
#   '2.6',
#   '0.098',
#   '25.0',
#   '67.0',
#   '0.9968',
#   '3.2',
#   '0.68',
#   '9.8',
#   '5'],
#  ['7.8',
#   '0.76',
#   '0.04',
#   '2.3',
#   '0.092',
#   '15.0',
#   '54.0',
#   '0.997',
#   '3.26',
#   '0.65',
#   '9.8',
#   '5'],
#  ['11.2',
#   '0.28',
#   '0.56',
#   '1.9',
#   '0.075',
#   '17.0',
#   '60.0',
#   '0.998',
#   '3.16',
#   '0.58',
#   '9.8',
#   '6'],
#  ['7.4',
#   '0.7',
#   '0.0',
#   '1.9',
#   '0.076',
#   '11.0',
#   '34.0',
#   '0.9978',
#   '3.51',
#   '0.56',
#   '9.4',
#   '5']]

# %%
file.close()

# %%
rows[0]
# Out:
# ['7.4',
#  '0.7',
#  '0.0',
#  '1.9',
#  '0.076',
#  '11.0',
#  '34.0',
#  '0.9978',
#  '3.51',
#  '0.56',
#  '9.4',
#  '5']

# %%
num_top_words=1000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data('winequality-red.csv', num_words=num_top_words)
# Out:
# ...
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
train_data
# Out:
# array([list([1, 14, 22, 16, 43, 530, 973, 2, 2, 65, 458, 2, 66, 2, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 2, 2, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2, 19, 14, 22, 4, 2, 2, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 2, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2, 2, 16, 480, 66, 2, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 2, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 2, 15, 256, 4, 2, 7, 2, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 2, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2, 56, 26, 141, 6, 194, 2, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 2, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 2, 88, 12, 16, 283, 5, 16, 2, 113, 103, 32, 15, 16, 2, 19, 178, 32]),
# ...

# %%
x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model_wines = Create3LModel(num_top_words=num_top_words, hl1 = 16, hl2 = 8)

model_wines.summary()

model_wines.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['acc'])

history_wines = model_wines.fit(x_train, y_train,
                            epochs=50,
                            batch_size=256,
                            validation_data=(x_val, y_val))
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_30 (Dense)            (None, 16)                16016
#
#  dense_31 (Dense)            (None, 8)                 136
#
#  dense_32 (Dense)            (None, 1)                 9
#
# ...
# Total params: 16161 (63.13 KB)
# Trainable params: 16161 (63.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 98/98 [==============================] - 2s 11ms/step - loss: 0.4898 - acc: 0.7781 - val_loss: 0.3839 - val_acc: 0.8385
# Epoch 2/50
# 98/98 [==============================] - 1s 7ms/step - loss: 0.3415 - acc: 0.8596 - val_loss: 0.3353 - val_acc: 0.8583
# Epoch 3/50
# 98/98 [==============================] - 1s 6ms/step - loss: 0.3159 - acc: 0.8693 - val_loss: 0.3286 - val_acc: 0.8604
# Epoch 4/50
# ...

# %%
num_top_words=500
(train_data, train_labels), (test_data, test_labels) = imdb.load_data('winequality-red.csv', num_words=num_top_words)
x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model_wines_500 = Create3LModel(num_top_words=num_top_words, hl1 = 16, hl2 = 8)

model_wines_500.summary()

model_wines_500.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['acc'])

history_wines_500 = model_wines_500.fit(x_train, y_train,
                            epochs=50,
                            batch_size=256,
                            validation_data=(x_val, y_val))
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_33 (Dense)            (None, 16)                8016
#
#  dense_34 (Dense)            (None, 8)                 136
#
#  dense_35 (Dense)            (None, 1)                 9
#
# ...
# Total params: 8161 (31.88 KB)
# Trainable params: 8161 (31.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 98/98 [==============================] - 2s 12ms/step - loss: 0.5417 - acc: 0.7270 - val_loss: 0.4382 - val_acc: 0.8061
# Epoch 2/50
# 98/98 [==============================] - 1s 6ms/step - loss: 0.4031 - acc: 0.8225 - val_loss: 0.3992 - val_acc: 0.8210
# Epoch 3/50
# 98/98 [==============================] - 1s 6ms/step - loss: 0.3788 - acc: 0.8335 - val_loss: 0.3831 - val_acc: 0.8327
# Epoch 4/50
# ...

# %%
from keras import regularizers

# L1 regularization
regularizers.l1(0.001)

# L2 regularization
regularizers.l2(0.001)

# L1 and L2 regularization at the same time
regularizers.l1_l2(l1=0.001, l2=0.001)

# %%
def Create3LModelL1(num_top_words, hl1 = 8, hl2 = 4):
    model = models.Sequential()
    model.add(layers.Dense(hl1, kernel_regularizer=regularizers.l1(0.001),
                           activation='relu', input_shape=(num_top_words,)))
    model.add(layers.Dense(hl2, kernel_regularizer=regularizers.l1(0.001),
                           activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    return model

def Create3LModelL2(num_top_words, hl1 = 8, hl2 = 4):
    model = models.Sequential()
    model.add(layers.Dense(hl1, kernel_regularizer=regularizers.l2(0.001),
                           activation='relu', input_shape=(num_top_words,)))
    model.add(layers.Dense(hl2, kernel_regularizer=regularizers.l2(0.001),
                           activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    return model

def Create3LModelL1L2(num_top_words, hl1 = 8, hl2 = 4):
    model = models.Sequential()
    model.add(layers.Dense(hl1, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001),
                           activation='relu', input_shape=(num_top_words,)))
    model.add(layers.Dense(hl2, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001),
                           activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    return model

# %%
def Create3LModelL1Dropout(num_top_words, hl1 = 8, hl2 = 4, probdrop=0.5):
    model = models.Sequential()
    model.add(layers.Dense(hl1, kernel_regularizer=regularizers.l1(0.001),
                           activation='relu', input_shape=(num_top_words,)))
    model.add(layers.Dropout(probdrop))
    model.add(layers.Dense(hl2, kernel_regularizer=regularizers.l1(0.001),
                           activation='relu'))
    model.add(layers.Dropout(probdrop))
    model.add(layers.Dense(1, activation='sigmoid'))
    return model

# %%
num_top_words=500
(train_data, train_labels), (test_data, test_labels) = imdb.load_data('winequality-red.csv', num_words=num_top_words)
x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model_wines_L1 = Create3LModelL1(num_top_words=num_top_words, hl1 = 16, hl2 = 8)

model_wines_L1.summary()

model_wines_L1.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['acc'])

history_wines_L1 = model_wines_L1.fit(x_train, y_train,
                            epochs=50,
                            batch_size=256,
                            validation_data=(x_val, y_val))
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_42 (Dense)            (None, 16)                8016
#
#  dense_43 (Dense)            (None, 8)                 136
#
#  dense_44 (Dense)            (None, 1)                 9
#
# ...
# Total params: 8161 (31.88 KB)
# Trainable params: 8161 (31.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 98/98 [==============================] - 2s 10ms/step - loss: 0.8401 - acc: 0.7393 - val_loss: 0.6542 - val_acc: 0.8114
# Epoch 2/50
# 98/98 [==============================] - 1s 6ms/step - loss: 0.5947 - acc: 0.8209 - val_loss: 0.5575 - val_acc: 0.8280
# Epoch 3/50
# 98/98 [==============================] - 1s 5ms/step - loss: 0.5358 - acc: 0.8294 - val_loss: 0.5235 - val_acc: 0.8289
# Epoch 4/50
# ...

# %%
num_top_words=500
(train_data, train_labels), (test_data, test_labels) = imdb.load_data('winequality-red.csv', num_words=num_top_words)
x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model_wines_L2 = Create3LModelL2(num_top_words=num_top_words, hl1 = 16, hl2 = 8)

model_wines_L2.summary()

model_wines_L2.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['acc'])

history_wines_L2 = model_wines_L2.fit(x_train, y_train,
                            epochs=50,
                            batch_size=256,
                            validation_data=(x_val, y_val))
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_45 (Dense)            (None, 16)                8016
#
#  dense_46 (Dense)            (None, 8)                 136
#
#  dense_47 (Dense)            (None, 1)                 9
#
# ...
# Total params: 8161 (31.88 KB)
# Trainable params: 8161 (31.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 98/98 [==============================] - 1s 7ms/step - loss: 0.5864 - acc: 0.7438 - val_loss: 0.4836 - val_acc: 0.8048
# Epoch 2/50
# 98/98 [==============================] - 0s 5ms/step - loss: 0.4454 - acc: 0.8239 - val_loss: 0.4301 - val_acc: 0.8276
# Epoch 3/50
# 98/98 [==============================] - 1s 6ms/step - loss: 0.4177 - acc: 0.8321 - val_loss: 0.4272 - val_acc: 0.8278
# Epoch 4/50
# ...

# %%
num_top_words=500
(train_data, train_labels), (test_data, test_labels) = imdb.load_data('winequality-red.csv', num_words=num_top_words)
x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model_wines_L1L2 = Create3LModelL1L2(num_top_words=num_top_words, hl1 = 16, hl2 = 8)

model_wines_L1L2.summary()

model_wines_L1L2.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['acc'])

history_wines_L1L2 = model_wines_L1L2.fit(x_train, y_train,
                            epochs=50,
                            batch_size=256,
                            validation_data=(x_val, y_val))
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_48 (Dense)            (None, 16)                8016
#
#  dense_49 (Dense)            (None, 8)                 136
#
#  dense_50 (Dense)            (None, 1)                 9
#
# ...
# Total params: 8161 (31.88 KB)
# Trainable params: 8161 (31.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 98/98 [==============================] - 4s 24ms/step - loss: 0.8762 - acc: 0.7228 - val_loss: 0.6685 - val_acc: 0.8037
# Epoch 2/50
# 98/98 [==============================] - 0s 5ms/step - loss: 0.5998 - acc: 0.8182 - val_loss: 0.5758 - val_acc: 0.8154
# Epoch 3/50
# 98/98 [==============================] - 0s 5ms/step - loss: 0.5408 - acc: 0.8280 - val_loss: 0.5302 - val_acc: 0.8270
# Epoch 4/50
# ...

# %%
num_top_words=500
(train_data, train_labels), (test_data, test_labels) = imdb.load_data('winequality-red.csv', num_words=num_top_words)
x_train, y_train  = vectorize_data_float_labels(train_data, train_labels, num_top_words)
x_val, y_val = vectorize_data_float_labels(test_data, test_labels, num_top_words)

model_wines_Dropout = Create3LModelL1Dropout(num_top_words=num_top_words, hl1 = 16, hl2 = 8)

model_wines_Dropout.summary()

model_wines_Dropout.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['acc'])

history_wines_Dropout = model_wines_Dropout.fit(x_train, y_train,
                            epochs=50,
                            batch_size=256,
                            validation_data=(x_val, y_val))
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_51 (Dense)            (None, 16)                8016
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_52 (Dense)            (None, 8)                 136
#
#  dropout_1 (Dropout)         (None, 8)                 0
#
#  dense_53 (Dense)            (None, 1)                 9
#
# ...
# Total params: 8161 (31.88 KB)
# Trainable params: 8161 (31.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 98/98 [==============================] - 2s 9ms/step - loss: 0.9686 - acc: 0.5416 - val_loss: 0.7969 - val_acc: 0.7496
# Epoch 2/50
# 98/98 [==============================] - 1s 6ms/step - loss: 0.7240 - acc: 0.6444 - val_loss: 0.6315 - val_acc: 0.8019
# Epoch 3/50
# ...

# %%
acc_wines = history_wines.history['acc']
val_acc_wines = history_wines.history['val_acc']
acc_wines_500 = history_wines_500.history['acc']
val_acc_wines_500 = history_wines_500.history['val_acc']

# %%
def PlotAccuracyComparison(acc1, val_acc1, acc2, val_acc2, lab1 = '1', lab2 = '2'):
    plt.clf()   # clear figure
    plt.rcParams['figure.figsize'] = (25.0, 5.0) # set default size of plots
    epochs = range(len(acc1))
    plt.plot(epochs, acc1, 'bo', label='Training accuracy for ' + lab1)
    plt.plot(epochs, val_acc1, 'b', label='Validation accuracy for ' + lab1)
    plt.plot(epochs, acc2, 'ro', label='Training accuracy for ' + lab2)
    plt.plot(epochs, val_acc2, 'r', label='Validation accuracy for ' + lab2)
    plt.title('Training and Validation Accuracies wines dataset')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# %%
PlotAccuracyComparison(acc_wines, val_acc_wines, acc_wines_500, val_acc_wines_500, 'wines 1000 examples, 50 epochs', 'wines 500 examples, 50 epochs')

# %% [markdown]
# The graph shows the accuracy during subsequent learning epochs. It can be concluded that a larger set provides higher accuracy (over 0.95). However, the model trained on a set of 500 elements also achieves high accuracies of about 0.85 on the validation set. both models for the validation set have an accuracy of approximately 0.8

# %%
acc_wines_L1 = history_wines_L1.history['acc']
val_acc_wines_L1 = history_wines_L1.history['val_acc']
acc_wines_L2 = history_wines_L2.history['acc']
val_acc_wines_L2 = history_wines_L2.history['val_acc']
acc_wines_L1L2 = history_wines_L1L2.history['acc']
val_acc_wines_L1L2 = history_wines_L1L2.history['val_acc']
acc_wines_Dropout = history_wines_Dropout.history['acc']
val_acc_wines_Dropout = history_wines_Dropout.history['val_acc']

# %%
def PlotAccuracyComparison(acc1, val_acc1, acc2, val_acc2, acc3, val_acc3, acc4, val_acc4, lab1 = '1', lab2 = '2', lab3 = '3', lab4 = '4'):
    plt.clf()   # clear figure
    plt.rcParams['figure.figsize'] = (25.0, 5.0) # set default size of plots
    epochs = range(len(acc1))
    plt.plot(epochs, acc1, 'bo', label='Training accuracy for ' + lab1)
    plt.plot(epochs, val_acc1, 'b', label='Validation accuracy for ' + lab1)
    plt.plot(epochs, acc2, 'ro', label='Training accuracy for ' + lab2)
    plt.plot(epochs, val_acc2, 'r', label='Validation accuracy for ' + lab2)
    plt.plot(epochs, acc3, 'go', label='Training accuracy for ' + lab3)
    plt.plot(epochs, val_acc3, 'g', label='Validation accuracy for ' + lab3)
    plt.plot(epochs, acc4, 'co', label='Training accuracy for ' + lab4)
    plt.plot(epochs, val_acc4, 'c', label='Validation accuracy for ' + lab4)
    plt.title('Training and Validation Accuracies wines dataset')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# %%
PlotAccuracyComparison(acc_wines_L1, val_acc_wines_L1, acc_wines_L2, val_acc_wines_L2, acc_wines_L1L2, val_acc_wines_L1L2, acc_wines_Dropout, val_acc_wines_Dropout, 'wines L1, 50 epochs', 'wines L2, 50 epochs', 'wines L1L2, 50 epochs', 'wines Dropout')

# %% [markdown]
# After applying regularizations and dropout, the L2 model has the highest accuracy in the training set, and the one with dropout has the lowest accuracy. In the case of accuracy on the validation set, it is very similar, already in the first epochs it reaches values of approximately 0.85 in all cases.

# %%
import matplotlib.pyplot as plt

# %%
def PlotLossComparison(loss1, val_loss1, loss2, val_loss2, lab1 = '1', lab2 = '2'):
    plt.clf()   # clear figure
    plt.rcParams['figure.figsize'] = (25.0, 5.0) # set default size of plots
    epochs = range(len(loss1))
    plt.plot(epochs, loss1, 'bo', label='Training loss for ' + lab1)
    plt.plot(epochs, val_loss1, 'b', label='Validation loss for ' + lab1)
    plt.plot(epochs, loss2, 'ro', label='Training loss for ' + lab2)
    plt.plot(epochs, val_loss2, 'r', label='Validation loss for ' + lab2)
    plt.title('Training and Validation Losses')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
def PlotLoss_2_Comparison(loss1, val_loss1, loss2, val_loss2, loss3, val_loss3, loss4, val_loss4, lab1 = '1', lab2 = '2', lab3 = '3', lab4 = '4'):
    plt.clf()   # clear figure
    plt.rcParams['figure.figsize'] = (25.0, 5.0) # set default size of plots
    epochs = range(len(loss1))
    plt.plot(epochs, loss1, 'bo', label='Training loss for ' + lab1)
    plt.plot(epochs, val_loss1, 'b', label='Validation loss for ' + lab1)
    plt.plot(epochs, loss2, 'ro', label='Training loss for ' + lab2)
    plt.plot(epochs, val_loss2, 'r', label='Validation loss for ' + lab2)
    plt.plot(epochs, loss3, 'go', label='Training loss for ' + lab3)
    plt.plot(epochs, val_loss3, 'g', label='Validation loss for ' + lab3)
    plt.plot(epochs, loss4, 'co', label='Training loss for ' + lab4)
    plt.plot(epochs, val_loss4, 'c', label='Validation loss for ' + lab4)
    plt.title('Training and Validation Losses')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
# Compare the losses of three training processes
loss_wines = history_wines.history['loss']
val_loss_wines = history_wines.history['val_loss']
loss_wines_500 = history_wines_500.history['loss']
val_loss_wines_500 = history_wines_500.history['val_loss']

# %%
PlotLossComparison(loss_wines, val_loss_wines, loss_wines_500, val_loss_wines_500, 'wines 1000 examples, 50 epochs', 'wines 500 examples 50 epochs')

# %% [markdown]
# Loss graphs before applying regularization and dropout indicate that the model is overtrained, reducing the number of elements in the data set significantly reduces the values of the loss function, but the model still needs to be improved.

# %%
# Compare the losses of three training processes
loss_wines_L1 = history_wines_L1.history['loss']
val_loss_wines_L1 = history_wines_L1.history['val_loss']
loss_wines_L2 = history_wines_L2.history['loss']
val_loss_wines_L2 = history_wines_L2.history['val_loss']
loss_wines_L1L2 = history_wines_L1L2.history['loss']
val_loss_wines_L1L2 = history_wines_L1L2.history['val_loss']
loss_wines_Dropout = history_wines_Dropout.history['loss']
val_loss_wines_Dropout = history_wines_Dropout.history['val_loss']
PlotLoss_2_Comparison(loss_wines_L1, val_loss_wines_L1, loss_wines_L2, val_loss_wines_L2, loss_wines_L1L2, val_loss_wines_L1L2, loss_wines_Dropout, val_loss_wines_Dropout, 'wines L1, 50 epochs', 'wines L2, 50 epochs', 'wines L1L2, 50 epochs', 'wines Dropout')

# %% [markdown]
# The use of regularization and dropout has a positive effect on the overtraining phenomenon and it is effectively eliminated. There are fluctuations in the graphs, which can be worked on by improving the model, but the loss values are getting smaller around (0.5), and the model itself does not adapt to the patterns as much as in cases without dropout and regularization

# %%
argmax1 = np.argmax(val_acc_wines)
print ('Max accuracy for model 1 is: ', val_acc_wines[argmax1], ', achieved in the ', argmax1 , 'epoch.')
argmax2 = np.argmax(val_acc_wines_500)
print ('Max accuracy for model 1 is: ', val_acc_wines_500[argmax2], ', achieved in the ', argmax2 , 'epoch.')
# Out:
# Max accuracy for model 1 is:  0.8603600263595581 , achieved in the  2 epoch.
# Max accuracy for model 1 is:  0.8327199816703796 , achieved in the  3 epoch.

# %%
argmax3 = np.argmax(val_acc_wines_L1)
print ('Max accuracy for model 1 is: ', val_acc_wines_L1[argmax3], ', achieved in the ', argmax1 , 'epoch.')
argmax4 = np.argmax(val_acc_wines_L2)
print ('Max accuracy for model 1 is: ', val_acc_wines_L2[argmax4], ', achieved in the ', argmax2 , 'epoch.')
argmax5 = np.argmax(val_acc_wines_L1L2)
print ('Max accuracy for model 1 is: ', val_acc_wines_L1L2[argmax5], ', achieved in the ', argmax3 , 'epoch.')
argmax6 = np.argmax(val_acc_wines_Dropout)
print ('Max accuracy for model 1 is: ', val_acc_wines_Dropout[argmax6], ', achieved in the ', argmax4 , 'epoch.')
# Out:
# Max accuracy for model 1 is:  0.8340799808502197 , achieved in the  2 epoch.
# Max accuracy for model 1 is:  0.8345199823379517 , achieved in the  3 epoch.
# Max accuracy for model 1 is:  0.8340399861335754 , achieved in the  38 epoch.
# Max accuracy for model 1 is:  0.8320000171661377 , achieved in the  16 epoch.
